# %% [markdown]
# # Artificial Intelligence Nanodegree
#
# ## Convolutional Neural Networks
#
# ---
#
# In this notebook, we train a CNN to classify images from the CIFAR-10 database.
#
# ### 1. Load CIFAR-10 Database

# %%
import keras
from keras.datasets import cifar10

# load the pre-shuffled train and test data
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
# Out:
# Using TensorFlow backend.
# Downloading data from http://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# Untaring file...

# %% [markdown]
# ### 2. Visualize the First 24 Training Images

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

fig = plt.figure(figsize=(20,5))
for i in range(36):
    ax = fig.add_subplot(3, 12, i + 1, xticks=[], yticks=[])
    ax.imshow(np.squeeze(x_train[i]))

# %% [markdown]
# ### 3. Rescale the Images by Dividing Every Pixel in Every Image by 255

# %%
# rescale [0,255] --> [0,1]
x_train = x_train.astype('float32')/255
x_test = x_test.astype('float32')/255

# %% [markdown]
# ### 4.  Break Dataset into Training, Testing, and Validation Sets

# %%
from keras.utils import np_utils

# one-hot encode the labels
num_classes = len(np.unique(y_train))
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

# break training set into training and validation sets
(x_train, x_valid) = x_train[5000:], x_train[:5000]
(y_train, y_valid) = y_train[5000:], y_train[:5000]

# print shape of training set
print('x_train shape:', x_train.shape)

# print number of training, validation, and test images
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
print(x_valid.shape[0], 'validation samples')
# Out:
# x_train shape: (45000, 32, 32, 3)
# 45000 train samples
# 10000 test samples
# 5000 validation samples

# %% [markdown]
# ### 5. Define the Model Architecture

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout

model = Sequential()
model.add(Conv2D(filters=16, kernel_size=2, padding='same', activation='relu', 
                        input_shape=(32, 32, 3)))
model.add(MaxPooling2D(pool_size=2))
model.add(Conv2D(filters=32, kernel_size=2, padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Conv2D(filters=64, kernel_size=2, padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.3))
model.add(Flatten())
model.add(Dense(500, activation='relu'))
model.add(Dropout(0.4))
model.add(Dense(10, activation='softmax'))

model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 32, 32, 16)        208
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 16, 16, 16)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 16, 16, 32)        2080
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 8, 8, 32)          0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 8, 8, 64)          8256
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 4, 4, 64)          0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 4, 4, 64)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 1024)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 500)               512500
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 500)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                5010
# =================================================================
# Total params: 528,054.0
# Trainable params: 528,054.0
# Non-trainable params: 0.0
# _________________________________________________________________

# %% [markdown]
# ### 6. Compile the Model

# %%
# compile the model
model.compile(loss='categorical_crossentropy', optimizer='rmsprop', 
                  metrics=['accuracy'])

# %% [markdown]
# ### 7. Train the Model

# %%
from keras.callbacks import ModelCheckpoint   

# train the model
checkpointer = ModelCheckpoint(filepath='model.weights.best.hdf5', verbose=1, 
                               save_best_only=True)
hist = model.fit(x_train, y_train, batch_size=32, epochs=100,
          validation_data=(x_valid, y_valid), callbacks=[checkpointer], 
          verbose=2, shuffle=True)
# Out:
# Train on 45000 samples, validate on 5000 samples
# Epoch 1/100
# Epoch 00000: val_loss improved from inf to 1.45564, saving model to model.weights.best.hdf5
# 18s - loss: 1.5865 - acc: 0.4258 - val_loss: 1.4556 - val_acc: 0.4798
# Epoch 2/100
# Epoch 00001: val_loss improved from 1.45564 to 1.15166, saving model to model.weights.best.hdf5
# 11s - loss: 1.2912 - acc: 0.5398 - val_loss: 1.1517 - val_acc: 0.5922
# Epoch 3/100
# Epoch 00002: val_loss improved from 1.15166 to 1.05024, saving model to model.weights.best.hdf5
# 10s - loss: 1.1796 - acc: 0.5793 - val_loss: 1.0502 - val_acc: 0.6286
# Epoch 4/100
# Epoch 00003: val_loss did not improve
# 11s - loss: 1.1113 - acc: 0.6093 - val_loss: 1.0900 - val_acc: 0.6196
# Epoch 5/100
# Epoch 00004: val_loss did not improve
# 11s - loss: 1.0736 - acc: 0.6231 - val_loss: 1.1149 - val_acc: 0.6038
# Epoch 6/100
# Epoch 00005: val_loss improved from 1.05024 to 0.97745, saving model to model.weights.best.hdf5
# 11s - loss: 1.0523 - acc: 0.6363 - val_loss: 0.9775 - val_acc: 0.6600
# Epoch 7/100
# Epoch 00006: val_loss did not improve
# 11s - loss: 1.0327 - acc: 0.6424 - val_loss: 1.0715 - val_acc: 0.6442
# Epoch 8/100
# Epoch 00007: val_loss improved from 0.97745 to 0.95369, saving model to model.weights.best.hdf5
# 11s - loss: 1.0241 - acc: 0.6483 - val_loss: 0.9537 - val_acc: 0.6752
# Epoch 9/100
# Epoch 00008: val_loss did not improve
# 12s - loss: 1.0098 - acc: 0.6544 - val_loss: 1.0501 - val_acc: 0.6680
# Epoch 10/100
# Epoch 00009: val_loss did not improve
# 11s - loss: 1.0081 - acc: 0.6565 - val_loss: 1.1383 - val_acc: 0.6384
# Epoch 11/100
# Epoch 00010: val_loss did not improve
# 11s - loss: 1.0104 - acc: 0.6582 - val_loss: 1.0562 - val_acc: 0.6384
# Epoch 12/100
# Epoch 00011: val_loss did not improve
# 11s - loss: 1.0088 - acc: 0.6599 - val_loss: 0.9947 - val_acc: 0.6762
# Epoch 13/100
# Epoch 00012: val_loss did not improve
# 11s - loss: 1.0115 - acc: 0.6586 - val_loss: 1.0726 - val_acc: 0.6560
# Epoch 14/100
# Epoch 00013: val_loss did not improve
# 11s - loss: 1.0181 - acc: 0.6575 - val_loss: 0.9961 - val_acc: 0.6752
# Epoch 15/100
# Epoch 00014: val_loss did not improve
# 11s - loss: 1.0333 - acc: 0.6559 - val_loss: 1.3143 - val_acc: 0.6084
# Epoch 16/100
# Epoch 00015: val_loss did not improve
# 11s - loss: 1.0517 - acc: 0.6499 - val_loss: 1.0057 - val_acc: 0.6752
# Epoch 17/100
# Epoch 00016: val_loss did not improve
# 11s - loss: 1.0706 - acc: 0.6446 - val_loss: 1.0371 - val_acc: 0.6630
# Epoch 18/100
# Epoch 00017: val_loss did not improve
# 11s - loss: 1.0976 - acc: 0.6390 - val_loss: 0.9896 - val_acc: 0.6792
# Epoch 19/100
# Epoch 00018: val_loss improved from 0.95369 to 0.94754, saving model to model.weights.best.hdf5
# 11s - loss: 1.1134 - acc: 0.6320 - val_loss: 0.9475 - val_acc: 0.6832
# Epoch 20/100
# Epoch 00019: val_loss did not improve
# 11s - loss: 1.1286 - acc: 0.6251 - val_loss: 1.4016 - val_acc: 0.6074
# Epoch 21/100
# Epoch 00020: val_loss did not improve
# 11s - loss: 1.1543 - acc: 0.6209 - val_loss: 1.3846 - val_acc: 0.5648
# Epoch 22/100
# Epoch 00021: val_loss did not improve
# 11s - loss: 1.1686 - acc: 0.6153 - val_loss: 1.0905 - val_acc: 0.6304
# Epoch 23/100
# Epoch 00022: val_loss did not improve
# 11s - loss: 1.1809 - acc: 0.6109 - val_loss: 1.0695 - val_acc: 0.6382
# Epoch 24/100
# Epoch 00023: val_loss did not improve
# 11s - loss: 1.1996 - acc: 0.6050 - val_loss: 1.3169 - val_acc: 0.5818
# Epoch 25/100
# Epoch 00024: val_loss did not improve
# 11s - loss: 1.2177 - acc: 0.5960 - val_loss: 1.1495 - val_acc: 0.6176
# Epoch 26/100
# Epoch 00025: val_loss did not improve
# 11s - loss: 1.2287 - acc: 0.5947 - val_loss: 1.2512 - val_acc: 0.6104
# Epoch 27/100
# Epoch 00026: val_loss did not improve
# 11s - loss: 1.2554 - acc: 0.5868 - val_loss: 1.5037 - val_acc: 0.4808
# Epoch 28/100
# Epoch 00027: val_loss did not improve
# 11s - loss: 1.2766 - acc: 0.5805 - val_loss: 1.2993 - val_acc: 0.5808
# Epoch 29/100
# Epoch 00028: val_loss did not improve
# 11s - loss: 1.2831 - acc: 0.5762 - val_loss: 1.1706 - val_acc: 0.5874
# Epoch 30/100
# Epoch 00029: val_loss did not improve
# 11s - loss: 1.2933 - acc: 0.5726 - val_loss: 1.3756 - val_acc: 0.5294
# Epoch 31/100
# Epoch 00030: val_loss did not improve
# 11s - loss: 1.3107 - acc: 0.5677 - val_loss: 1.2666 - val_acc: 0.5986
# Epoch 32/100
# Epoch 00031: val_loss did not improve
# 11s - loss: 1.3223 - acc: 0.5629 - val_loss: 2.0432 - val_acc: 0.4418
# Epoch 33/100
# Epoch 00032: val_loss did not improve
# 11s - loss: 1.3424 - acc: 0.5524 - val_loss: 4.1603 - val_acc: 0.4130
# Epoch 34/100
# Epoch 00033: val_loss did not improve
# 11s - loss: 1.3591 - acc: 0.5499 - val_loss: 1.2732 - val_acc: 0.5970
# Epoch 35/100
# Epoch 00034: val_loss did not improve
# 11s - loss: 1.3649 - acc: 0.5454 - val_loss: 3.1046 - val_acc: 0.3506
# Epoch 36/100
# Epoch 00035: val_loss did not improve
# 11s - loss: 1.3784 - acc: 0.5423 - val_loss: 2.4926 - val_acc: 0.5086
# Epoch 37/100
# Epoch 00036: val_loss did not improve
# 11s - loss: 1.3986 - acc: 0.5354 - val_loss: 1.3467 - val_acc: 0.5354
# Epoch 38/100
# Epoch 00037: val_loss did not improve
# 11s - loss: 1.4105 - acc: 0.5284 - val_loss: 1.5708 - val_acc: 0.4652
# Epoch 39/100
# Epoch 00038: val_loss did not improve
# 11s - loss: 1.4352 - acc: 0.5197 - val_loss: 1.3050 - val_acc: 0.5396
# Epoch 40/100
# Epoch 00039: val_loss did not improve
# 11s - loss: 1.4449 - acc: 0.5183 - val_loss: 1.9267 - val_acc: 0.4830
# Epoch 41/100
# Epoch 00040: val_loss did not improve
# 11s - loss: 1.4423 - acc: 0.5158 - val_loss: 1.3278 - val_acc: 0.5366
# Epoch 42/100
# Epoch 00041: val_loss did not improve
# 11s - loss: 1.4516 - acc: 0.5160 - val_loss: 1.9590 - val_acc: 0.4526
# Epoch 43/100
# Epoch 00042: val_loss did not improve
# 11s - loss: 1.4688 - acc: 0.5067 - val_loss: 1.2951 - val_acc: 0.5542
# Epoch 44/100
# Epoch 00043: val_loss did not improve
# 11s - loss: 1.4939 - acc: 0.4977 - val_loss: 1.4332 - val_acc: 0.4600
# Epoch 45/100
# Epoch 00044: val_loss did not improve
# 11s - loss: 1.5029 - acc: 0.4943 - val_loss: 1.3620 - val_acc: 0.5002
# Epoch 46/100
# Epoch 00045: val_loss did not improve
# 11s - loss: 1.5172 - acc: 0.4870 - val_loss: 1.6515 - val_acc: 0.5362
# Epoch 47/100
# Epoch 00046: val_loss did not improve
# 11s - loss: 1.5351 - acc: 0.4869 - val_loss: 1.9062 - val_acc: 0.4512
# Epoch 48/100
# Epoch 00047: val_loss did not improve
# 11s - loss: 1.5297 - acc: 0.4837 - val_loss: 1.3693 - val_acc: 0.5360
# Epoch 49/100
# Epoch 00048: val_loss did not improve
# 11s - loss: 1.5498 - acc: 0.4788 - val_loss: 1.5810 - val_acc: 0.5060
# Epoch 50/100
# Epoch 00049: val_loss did not improve
# 11s - loss: 1.5591 - acc: 0.4713 - val_loss: 1.7170 - val_acc: 0.4484
# Epoch 51/100
# Epoch 00050: val_loss did not improve
# 11s - loss: 1.5795 - acc: 0.4681 - val_loss: 1.7190 - val_acc: 0.4140
# Epoch 52/100
# Epoch 00051: val_loss did not improve
# 11s - loss: 1.5827 - acc: 0.4630 - val_loss: 1.5885 - val_acc: 0.4308
# Epoch 53/100
# Epoch 00052: val_loss did not improve
# 11s - loss: 1.6023 - acc: 0.4572 - val_loss: 1.8691 - val_acc: 0.4426
# Epoch 54/100
# Epoch 00053: val_loss did not improve
# 11s - loss: 1.6037 - acc: 0.4535 - val_loss: 1.8550 - val_acc: 0.4516
# Epoch 55/100
# Epoch 00054: val_loss did not improve
# 11s - loss: 1.6201 - acc: 0.4500 - val_loss: 1.4252 - val_acc: 0.4938
# Epoch 56/100
# Epoch 00055: val_loss did not improve
# 11s - loss: 1.6206 - acc: 0.4482 - val_loss: 1.3603 - val_acc: 0.5084
# Epoch 57/100
# Epoch 00056: val_loss did not improve
# 11s - loss: 1.6079 - acc: 0.4517 - val_loss: 1.3700 - val_acc: 0.5032
# Epoch 58/100
# Epoch 00057: val_loss did not improve
# 11s - loss: 1.6526 - acc: 0.4382 - val_loss: 1.5266 - val_acc: 0.4690
# Epoch 59/100
# Epoch 00058: val_loss did not improve
# 11s - loss: 1.6416 - acc: 0.4393 - val_loss: 1.5274 - val_acc: 0.4362
# Epoch 60/100
# Epoch 00059: val_loss did not improve
# 11s - loss: 1.6587 - acc: 0.4336 - val_loss: 1.5858 - val_acc: 0.4628
# Epoch 61/100
# Epoch 00060: val_loss did not improve
# 11s - loss: 1.6440 - acc: 0.4404 - val_loss: 1.4684 - val_acc: 0.4918
# Epoch 62/100
# Epoch 00061: val_loss did not improve
# 11s - loss: 1.6465 - acc: 0.4372 - val_loss: 1.4270 - val_acc: 0.5042
# Epoch 63/100
# Epoch 00062: val_loss did not improve
# 11s - loss: 1.6686 - acc: 0.4304 - val_loss: 1.5994 - val_acc: 0.4266
# Epoch 64/100
# Epoch 00063: val_loss did not improve
# 11s - loss: 1.6661 - acc: 0.4275 - val_loss: 1.4656 - val_acc: 0.4902
# Epoch 65/100
# Epoch 00064: val_loss did not improve
# 11s - loss: 1.6769 - acc: 0.4299 - val_loss: 1.4356 - val_acc: 0.4990
# Epoch 66/100
# Epoch 00065: val_loss did not improve
# 11s - loss: 1.6677 - acc: 0.4316 - val_loss: 1.4942 - val_acc: 0.4786
# Epoch 67/100
# Epoch 00066: val_loss did not improve
# 11s - loss: 1.6749 - acc: 0.4270 - val_loss: 1.5936 - val_acc: 0.4232
# Epoch 68/100
# Epoch 00067: val_loss did not improve
# 11s - loss: 1.6790 - acc: 0.4256 - val_loss: 1.5545 - val_acc: 0.4952
# Epoch 69/100
# Epoch 00068: val_loss did not improve
# 11s - loss: 1.6812 - acc: 0.4235 - val_loss: 1.6164 - val_acc: 0.4450
# Epoch 70/100
# Epoch 00069: val_loss did not improve
# 11s - loss: 1.6863 - acc: 0.4194 - val_loss: 1.7549 - val_acc: 0.4642
# Epoch 71/100
# Epoch 00070: val_loss did not improve
# 11s - loss: 1.6896 - acc: 0.4302 - val_loss: 1.5845 - val_acc: 0.4508
# Epoch 72/100
# Epoch 00071: val_loss did not improve
# 11s - loss: 1.6901 - acc: 0.4244 - val_loss: 1.5735 - val_acc: 0.4572
# Epoch 73/100
# Epoch 00072: val_loss did not improve
# 11s - loss: 1.6998 - acc: 0.4162 - val_loss: 2.4463 - val_acc: 0.4294
# Epoch 74/100
# Epoch 00073: val_loss did not improve
# 11s - loss: 1.7146 - acc: 0.4152 - val_loss: 2.0100 - val_acc: 0.3886
# Epoch 75/100
# Epoch 00074: val_loss did not improve
# 11s - loss: 1.7127 - acc: 0.4152 - val_loss: 1.5583 - val_acc: 0.4260
# Epoch 76/100
# Epoch 00075: val_loss did not improve
# 11s - loss: 1.7186 - acc: 0.4094 - val_loss: 1.7538 - val_acc: 0.3862
# Epoch 77/100
# Epoch 00076: val_loss did not improve
# 11s - loss: 1.7393 - acc: 0.4079 - val_loss: 1.5456 - val_acc: 0.4754
# Epoch 78/100
# Epoch 00077: val_loss did not improve
# 11s - loss: 1.7376 - acc: 0.4077 - val_loss: 1.5030 - val_acc: 0.4854
# Epoch 79/100
# Epoch 00078: val_loss did not improve
# 11s - loss: 1.7414 - acc: 0.4092 - val_loss: 2.2006 - val_acc: 0.3748
# Epoch 80/100
# Epoch 00079: val_loss did not improve
# 11s - loss: 1.7615 - acc: 0.4028 - val_loss: 1.6149 - val_acc: 0.4234
# Epoch 81/100
# Epoch 00080: val_loss did not improve
# 11s - loss: 1.7689 - acc: 0.3961 - val_loss: 1.5906 - val_acc: 0.4344
# Epoch 82/100
# Epoch 00081: val_loss did not improve
# 11s - loss: 1.7831 - acc: 0.3926 - val_loss: 1.7058 - val_acc: 0.3880
# Epoch 83/100
# Epoch 00082: val_loss did not improve
# 11s - loss: 1.8126 - acc: 0.3856 - val_loss: 1.6795 - val_acc: 0.4234
# Epoch 84/100
# Epoch 00083: val_loss did not improve
# 11s - loss: 1.8171 - acc: 0.3789 - val_loss: 1.5910 - val_acc: 0.4000
# Epoch 85/100
# Epoch 00084: val_loss did not improve
# 11s - loss: 1.8220 - acc: 0.3760 - val_loss: 2.1644 - val_acc: 0.3400
# Epoch 86/100
# Epoch 00085: val_loss did not improve
# 11s - loss: 1.8279 - acc: 0.3709 - val_loss: 2.0335 - val_acc: 0.4114
# Epoch 87/100
# Epoch 00086: val_loss did not improve
# 11s - loss: 1.7989 - acc: 0.3807 - val_loss: 1.8122 - val_acc: 0.4032
# Epoch 88/100
# Epoch 00087: val_loss did not improve
# 11s - loss: 1.8248 - acc: 0.3745 - val_loss: 1.6449 - val_acc: 0.4274
# Epoch 89/100
# Epoch 00088: val_loss did not improve
# 11s - loss: 1.8112 - acc: 0.3741 - val_loss: 1.5861 - val_acc: 0.4242
# Epoch 90/100
# Epoch 00089: val_loss did not improve
# 11s - loss: 1.8126 - acc: 0.3742 - val_loss: 1.5180 - val_acc: 0.4730
# Epoch 91/100
# Epoch 00090: val_loss did not improve
# 11s - loss: 1.8151 - acc: 0.3709 - val_loss: 1.7534 - val_acc: 0.3722
# Epoch 92/100
# Epoch 00091: val_loss did not improve
# 11s - loss: 1.8244 - acc: 0.3669 - val_loss: 2.7274 - val_acc: 0.2122
# Epoch 93/100
# Epoch 00092: val_loss did not improve
# 11s - loss: 1.8182 - acc: 0.3705 - val_loss: 1.6481 - val_acc: 0.4248
# Epoch 94/100
# Epoch 00093: val_loss did not improve
# 11s - loss: 1.7974 - acc: 0.3700 - val_loss: 1.9382 - val_acc: 0.3852
# Epoch 95/100
# Epoch 00094: val_loss did not improve
# 11s - loss: 1.8179 - acc: 0.3703 - val_loss: 1.6675 - val_acc: 0.3702
# Epoch 96/100
# Epoch 00095: val_loss did not improve
# 11s - loss: 1.8089 - acc: 0.3728 - val_loss: 1.5297 - val_acc: 0.4450
# Epoch 97/100
# Epoch 00096: val_loss did not improve
# 11s - loss: 1.8032 - acc: 0.3743 - val_loss: 1.6989 - val_acc: 0.3916
# Epoch 98/100
# Epoch 00097: val_loss did not improve
# 11s - loss: 1.8010 - acc: 0.3744 - val_loss: 1.5482 - val_acc: 0.4338
# Epoch 99/100
# Epoch 00098: val_loss did not improve
# 11s - loss: 1.8119 - acc: 0.3672 - val_loss: 1.6628 - val_acc: 0.4312
# Epoch 100/100
# Epoch 00099: val_loss did not improve
# 11s - loss: 1.8093 - acc: 0.3674 - val_loss: 1.9258 - val_acc: 0.3016

# %% [markdown]
# ### 8. Load the Model with the Best Validation Accuracy

# %%
# load the weights that yielded the best validation accuracy
model.load_weights('model.weights.best.hdf5')

# %% [markdown]
# ### 9. Calculate Classification Accuracy on Test Set

# %%
# evaluate and print test accuracy
score = model.evaluate(x_test, y_test, verbose=0)
print('\n', 'Test accuracy:', score[1])
# Out:
#  Test accuracy: 0.6732

# %% [markdown]
# ### 10. Visualize Some Predictions
#
# This may give you some insight into why the network is misclassifying certain objects.

# %%
# get predictions on the test set
y_hat = model.predict(x_test)

# define text labels (source: https://www.cs.toronto.edu/~kriz/cifar.html)
cifar10_labels = ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

# %%
# plot a random sample of test images, their predicted labels, and ground truth
fig = plt.figure(figsize=(20, 8))
for i, idx in enumerate(np.random.choice(x_test.shape[0], size=32, replace=False)):
    ax = fig.add_subplot(4, 8, i + 1, xticks=[], yticks=[])
    ax.imshow(np.squeeze(x_test[idx]))
    pred_idx = np.argmax(y_hat[idx])
    true_idx = np.argmax(y_test[idx])
    ax.set_title("{} ({})".format(cifar10_labels[pred_idx], cifar10_labels[true_idx]),
                 color=("green" if pred_idx == true_idx else "red"))
